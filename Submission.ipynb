# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir(r'C:\Users\Domain\Desktop\PROJECT@HERO_VIRED')
os.listdir()
# Out:
# ['06 Org Profiling Case Study Data.xlsx',
#  '06 Org Profiling Case Study.pptx.pdf']

# %%
df=pd.read_excel('06 Org Profiling Case Study Data.xlsx',sheet_name='Data')
df
# Out:
#                 Employee_Name  Salary  Terminated                  Position  \
# 0         Adinolfi, Wilson  K   62506           0   Production Technician I
# 1    Ait Sidi, Karthikeyan     104437           1                   Sr. DBA
# 2           Akinkuolie, Sarah   64955           1  Production Technician II
# 3                Alagbe,Trina   64991           0   Production Technician I
# 4            Anderson, Carol    50825           1   Production Technician I
# ..                        ...     ...         ...                       ...
# 306            Woodson, Jason   65893           0  Production Technician II
# 307        Ybarra, Catherine    48513           1   Production Technician I
# 308          Zamora, Jennifer  220450           0                       CIO
# 309               Zhou, Julia   89292           0              Data Analyst
# 310             Zima, Colleen   45046           0   Production Technician I
#
# ...

# %%
df.info()# Variables are read in right form of Dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_Name          311 non-null    object
#  1   Salary                 311 non-null    int64
#  2   Terminated             311 non-null    int64
#  3   Position               311 non-null    object
#  4   DOB                    311 non-null    datetime64[ns]
#  5   Gender                 311 non-null    object
#  6   Marital_Status         311 non-null    object
#  7   Hiring_Date            311 non-null    datetime64[ns]
#  8   Termination_Date       104 non-null    datetime64[ns]
#  9   Termination_Reason     311 non-null    object
#  10  Curr_Emp_Status        311 non-null    object
#  11  Department             311 non-null    object
#  12  Manager_Name           311 non-null    object
#  13  Manager_ID             303 non-null    float64
# ...

# %%
# To find whwether any Missing values present in the Dataframe 
df.isnull().any()
# Out:
# Employee_Name            False
# Salary                   False
# Terminated               False
# Position                 False
# DOB                      False
# Gender                   False
# Marital_Status           False
# Hiring_Date              False
# Termination_Date          True
# Termination_Reason       False
# Curr_Emp_Status          False
# Department               False
# Manager_Name             False
# Manager_ID                True
# Recruitment_Source       False
# Performance_Score        False
# Engagement_Survey        False
# Satisfaction_Score       False
# Num_Spc_Projects         False
# Last_Perf_Review_Date    False
# Dayslate30               False
# Num_Absences             False
# dtype: bool

# %%
#Finding Number of Missing values in each column
df.isnull().sum()
# Out:
# Employee_Name              0
# Salary                     0
# Terminated                 0
# Position                   0
# DOB                        0
# Gender                     0
# Marital_Status             0
# Hiring_Date                0
# Termination_Date         207
# Termination_Reason         0
# Curr_Emp_Status            0
# Department                 0
# Manager_Name               0
# Manager_ID                 8
# Recruitment_Source         0
# Performance_Score          0
# Engagement_Survey          0
# Satisfaction_Score         0
# Num_Spc_Projects           0
# Last_Perf_Review_Date      0
# Dayslate30                 0
# Num_Absences               0
# dtype: int64

# %%
df.shape#Size of a dataframe
# Out:
# (311, 22)

# %%
# Finding list of missing variables.
l=list(df.columns[df.isnull().any()])
l
# Out:
# ['Termination_Date', 'Manager_ID']

# %%
(df[l].isnull().sum()/df.shape[0]).round(2) # % missing values
# Out:
# Termination_Date    0.67
# Manager_ID          0.03
# dtype: float64

# %%
u=list(df.columns)
u
# Out:
# ['Employee_Name',
#  'Salary',
#  'Terminated',
#  'Position',
#  'DOB',
#  'Gender',
#  'Marital_Status',
#  'Hiring_Date',
#  'Termination_Date',
#  'Termination_Reason',
#  'Curr_Emp_Status',
#  'Department',
#  'Manager_Name',
#  'Manager_ID',
#  'Recruitment_Source',
#  'Performance_Score',
#  'Engagement_Survey',
#  'Satisfaction_Score',
#  'Num_Spc_Projects',
#  'Last_Perf_Review_Date',
#  'Dayslate30',
#  'Num_Absences']

# %%
# % Unique_values
for i in u:
    print(i,'------',round(df[i].nunique()/df.shape[0],3))
# Out:
# Employee_Name ------ 1.0
# Salary ------ 0.99
# Terminated ------ 0.006
# Position ------ 0.103
# DOB ------ 0.987
# Gender ------ 0.006
# Marital_Status ------ 0.016
# Hiring_Date ------ 0.325
# Termination_Date ------ 0.309
# Termination_Reason ------ 0.058
# Curr_Emp_Status ------ 0.01
# Department ------ 0.019
# Manager_Name ------ 0.068
# Manager_ID ------ 0.074
# Recruitment_Source ------ 0.029
# Performance_Score ------ 0.013
# Engagement_Survey ------ 0.383
# Satisfaction_Score ------ 0.016
# Num_Spc_Projects ------ 0.029
# Last_Perf_Review_Date ------ 0.441
# Dayslate30 ------ 0.023
# Num_Absences ------ 0.064

# %%
# Outliers are there for variable 'Engagement_Survey'
sns.boxplot(data=df,x='Engagement_Survey')
# Out:
# <AxesSubplot:xlabel='Engagement_Survey'>

# %%
df['Engagement_Survey'].describe()
# Out:
# count    311.000000
# mean       4.110000
# std        0.789938
# min        1.120000
# 25%        3.690000
# 50%        4.280000
# 75%        4.700000
# max        5.000000
# Name: Engagement_Survey, dtype: float64

# %%
sns.boxplot(data=df,x='Salary')
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
df['Salary'].describe(percentiles=[0.01,0.15,0.3,0.45,0.6,0.8,0.9,0.99])
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 1%        45398.800000
# 15%       51988.500000
# 30%       57748.000000
# 45%       61576.000000
# 50%       62810.000000
# 60%       64724.000000
# 80%       75188.000000
# 90%       95660.000000
# 99%      177250.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %%
df.duplicated().sum()# No duplicate records
# Out:
# 0

# %% [markdown]
# # Section-3

# %%
# Overall Summary of Numeric variables
temp=df.describe(percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99]).T
temp
# Out:
#                     count          mean           std       min         1%  \
# Salary              311.0  69020.684887  25156.636930  45046.00  45398.800
# Terminated          311.0      0.334405      0.472542      0.00      0.000
# Manager_ID          303.0     14.570957      8.078306      1.00      1.000
# Engagement_Survey   311.0      4.110000      0.789938      1.12      1.822
# Satisfaction_Score  311.0      3.890675      0.909241      1.00      2.000
# Num_Spc_Projects    311.0      1.218650      2.349421      0.00      0.000
# Dayslate30          311.0      0.414791      1.294519      0.00      0.000
# Num_Absences        311.0     10.237942      5.852596      1.00      1.000
#
#                          5%       25%       50%      75%       95%       99%  \
# Salary              46999.5  55501.50  62810.00  72036.0  108106.5  177250.0
# Terminated              0.0      0.00      0.00      1.0       1.0       1.0
# ...

# %%
#overall summary of Object varables
df.describe(include='object').T
# Out:
#                    count unique                      top freq
# Employee_Name        311    311         Sparks, Taylor      1
# Position             311     32  Production Technician I  137
# Gender               311      2                        F  176
# Marital_Status       311      5                   Single  137
# Termination_Reason   311     18        N/A-StillEmployed  207
# Curr_Emp_Status      311      3                   Active  207
# Department           311      6        Production         209
# Manager_Name         311     21           Brannon Miller   22
# Recruitment_Source   311      9                   Indeed   87
# Performance_Score    311      4              Fully Meets  243

# %%
# Overall summary of all the Variables
df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# Out:
# <ipython-input-168-ab01a29d3811>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# <ipython-input-168-ab01a29d3811>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# <ipython-input-168-ab01a29d3811>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
# ...

# %%
# Current vacancies present in the company 
# Terminated--1
df['Terminated'].sum()
# Out:
# 104

# %%
df[['Terminated','Department']]
# Out:
#      Terminated         Department
# 0             0  Production
# 1             1              IT/IS
# 2             1  Production
# 3             0  Production
# 4             1  Production
# ..          ...                ...
# 306           0  Production
# 307           1  Production
# 308           0              IT/IS
# 309           0              IT/IS
# 310           0  Production
#
# [311 rows x 2 columns]

# %%
#Vacancies in department
pd.crosstab(df['Department'],df['Terminated'])#High vacancies present in Production department.
# Out:
# Terminated              0   1
# Department
# Admin Offices           7   2
# Executive Office        1   0
# IT/IS                  40  10
# Production            126  83
# Sales                  26   5
# Software Engineering    7   4

# %%
# High Termination/vacancies is present in Production Department.
plt.figure(figsize=(18,7))
sns.countplot(data=df,x='Department',hue='Terminated')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
f=df.groupby('Termination_Reason').agg({'Terminated':['count']})
f
# Out:
#                                  Terminated
#                                       count
# Termination_Reason
# Another position                         20
# Fatal attraction                          1
# Learned that he is a gangster             1
# N/A-StillEmployed                       207
# attendance                                7
# career change                             9
# gross misconduct                          1
# hours                                     8
# maternity leave - did not return          3
# medical issues                            3
# military                                  4
# more money                               11
# no-call, no-show                          4
# performance                               4
# relocation out of area                    5
# retiring                                  4
# return to school                          5
# unhappy                                  14

# %%
f.sort_values(('Terminated', 'count'),ascending=False)
# Out:
#                                  Terminated
#                                       count
# Termination_Reason
# N/A-StillEmployed                       207
# Another position                         20
# unhappy                                  14
# more money                               11
# career change                             9
# hours                                     8
# attendance                                7
# relocation out of area                    5
# return to school                          5
# military                                  4
# no-call, no-show                          4
# performance                               4
# retiring                                  4
# maternity leave - did not return          3
# medical issues                            3
# Learned that he is a gangster             1
# gross misconduct                          1
# Fatal attraction                          1

# %%
plt.figure(figsize=(35,7))
sns.countplot(data=df,x='Termination_Reason',hue='Terminated');

# %%
df['Termination_Reason'].value_counts(normalize=True)
# 6.4% of the persons are terminated due to reason  Another Position
# 4.5% of the people are terminated since they were unhappy with company's policies------company policies should be improved.
# Out:
# N/A-StillEmployed                   0.665595
# Another position                    0.064309
# unhappy                             0.045016
# more money                          0.035370
# career change                       0.028939
# hours                               0.025723
# attendance                          0.022508
# relocation out of area              0.016077
# return to school                    0.016077
# retiring                            0.012862
# military                            0.012862
# no-call, no-show                    0.012862
# performance                         0.012862
# maternity leave - did not return    0.009646
# medical issues                      0.009646
# gross misconduct                    0.003215
# Fatal attraction                    0.003215
# Learned that he is a gangster       0.003215
# Name: Termination_Reason, dtype: float64

# %%
plt.figure(figsize=(100,20))
plt.bar(df['Position'],df['Salary'],edgecolor='black')
plt.show()

# %%
pos_sal=df.groupby('Position').agg({'Salary':['count','max']})
pos_sal.sort_values(('Salary',   'max'),ascending=False)
# Out:
#                              Salary
#                               count     max
# Position
# President & CEO                   1  250000
# CIO                               1  220450
# Director of Sales                 1  180000
# IT Director                       1  178000
# Director of Operations            1  170500
# IT Manager - Infra                1  157000
# Data Architect                    1  150290
# IT Manager - DB                   2  148999
# IT Manager - Support              1  138888
# Principal Data Architect          1  120000
# Database Administrator            5  114800
# BI Director                       1  110929
# Software Engineer                10  108987
# Sr. Network Engineer              5  107226
# Sr. Accountant                    2  106367
# Sr. DBA                           2  104437
# Enterprise Architect              1  103613
# BI Developer                      4   99020
# Data Analyst                      7   93554
# ...

# %%
#Absentism-----
df['Num_Absences']
# Out:
# 0       1
# 1      17
# 2       3
# 3      15
# 4       2
#        ..
# 306    13
# 307     4
# 308    16
# 309    11
# 310     2
# Name: Num_Absences, Length: 311, dtype: int64

# %%
max(df['Num_Absences'])
# Out:
# 20

# %%
sns.set_theme()

# %%
# More number of Irregular employees are present in the  Department Production.---They can be Terminated.
plt.figure(figsize=(50,10))

sns.countplot(data=df,x='Department',hue='Num_Absences')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
df['Termination_Reason'].value_counts(normalize=True)
# Out:
# N/A-StillEmployed                   0.665595
# Another position                    0.064309
# unhappy                             0.045016
# more money                          0.035370
# career change                       0.028939
# hours                               0.025723
# attendance                          0.022508
# relocation out of area              0.016077
# return to school                    0.016077
# retiring                            0.012862
# military                            0.012862
# no-call, no-show                    0.012862
# performance                         0.012862
# maternity leave - did not return    0.009646
# medical issues                      0.009646
# gross misconduct                    0.003215
# Fatal attraction                    0.003215
# Learned that he is a gangster       0.003215
# Name: Termination_Reason, dtype: float64

# %%
plt.figure(figsize=(30,10))
sns.countplot(data=df,x='Termination_Reason',hue='Satisfaction_Score');
# Many of current employees are have given low score due to some inconvenience in the company.
#Improving Comapny policies will help the company from the termination of current employees.

# %%
# Dissatisfaction of employees in comanys policies.
pd.crosstab(df['Termination_Reason'],df['Satisfaction_Score'])
# Out:
# Satisfaction_Score                1  2   3   4   5
# Termination_Reason
# Another position                  0  1   4   7   8
# Fatal attraction                  0  0   0   0   1
# Learned that he is a gangster     0  0   0   0   1
# N/A-StillEmployed                 2  5  75  56  69
# attendance                        0  0   2   4   1
# career change                     0  0   4   3   2
# gross misconduct                  0  0   0   0   1
# hours                             0  0   3   3   2
# maternity leave - did not return  0  0   0   1   2
# medical issues                    0  0   2   1   0
# military                          0  0   2   2   0
# more money                        0  0   3   3   5
# no-call, no-show                  0  0   3   1   0
# performance                       0  1   1   2   0
# relocation out of area            0  0   0   2   3
# retiring                          0  0   2   2   0
# return to school                  0  0   2   3   0
# ...

# %%
#Recruitment
df['Recruitment_Source'].value_counts()
# Out:
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: Recruitment_Source, dtype: int64

# %%
df['Performance_Score'].value_counts()
# Out:
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: Performance_Score, dtype: int64

# %%
# More number of freshers are recruited through Source:Indeed,Linked-in  and with better performance
p=pd.crosstab(df['Recruitment_Source'],df['Performance_Score'])
p.sort_values('Fully Meets',ascending=False)

#In future, for correct Hiring the company can post job notification in these sources.
# Out:
# Performance_Score        Exceeds  Fully Meets  Needs Improvement  PIP
# Recruitment_Source
# Indeed                        12           66                  4    5
# LinkedIn                       9           61                  3    3
# Google Search                  2           43                  3    1
# Employee Referral              5           25                  0    1
# Diversity Job Fair             6           18                  4    1
# CareerBuilder                  2           17                  4    0
# Website                        1           10                  0    2
# Other                          0            2                  0    0
# On-line Web application        0            1                  0    0

# %%
c_hire=df[df['Performance_Score'].isin(['Exceeds','Fully Meets'])] 
c_hire.shape
# Out:
# (280, 22)

# %%
#The company does not need this employees.So wrong Hiring is done in the company ----------Future Risk identified
w_hire=df[df['Performance_Score'].isin(['Needs Improvement','PIP'] or df['Terminated']==0)] 
w_hire
# Out:
#              Employee_Name  Salary  Terminated                  Position  \
# 23          Blount, Dianna   66441           0  Production Technician II
# 53           Cole, Spencer   59144           1   Production Technician I
# 54       Corleone, Michael   68051           0        Production Manager
# 67           Delarge, Alex   61568           0        Area Sales Manager
# 69         Desimone, Carl    53189           0   Production Technician I
# 72       Dietrich, Jenna     59231           0        Area Sales Manager
# 73          DiNocco, Lily    61584           0   Production Technician I
# 83          Erilus, Angela   56847           0  Production Technician II
# 84       Estremera, Miguel   60340           1   Production Technician I
# 85          Evensen, April   59124           1   Production Technician I
# 86          Exantus, Susan   99280           1         Software Engineer
# 90     Fernandes, Nilson     64057           0   Production Technician I
# ...

# %%
w_hire.shape
# Out:
# (31, 22)

# %%
# Here most of the cases the persons with 'Fully meets' performance are Terminated---- company should make note of it .
plt.figure(figsize=(14,7))
sns.countplot(data=df,x='Performance_Score',hue='Terminated');

# %%
df['Engagement_Survey'].value_counts()
# Out:
# 5.00    56
# 4.50    19
# 4.30    17
# 4.20    17
# 4.10    16
#         ..
# 2.60     1
# 4.94     1
# 3.11     1
# 3.51     1
# 3.08     1
# Name: Engagement_Survey, Length: 119, dtype: int64

# %%
df[['Engagement_Survey','Terminated']]
# Out:
#      Engagement_Survey  Terminated
# 0                 4.60           0
# 1                 4.96           1
# 2                 3.02           1
# 3                 4.84           0
# 4                 5.00           1
# ..                 ...         ...
# 306               4.07           0
# 307               3.20           1
# 308               4.60           0
# 309               5.00           0
# 310               4.50           0
#
# [311 rows x 2 columns]

# %%
# People with low_engagement score(low performance) in which we can replace them talented freshers.
lp=df[(df['Engagement_Survey']<3) & (df['Terminated']==0)]
lp
# Out:
#              Employee_Name  Salary  Terminated                  Position  \
# 23          Blount, Dianna   66441           0  Production Technician II
# 67           Delarge, Alex   61568           0        Area Sales Manager
# 69         Desimone, Carl    53189           0   Production Technician I
# 72       Dietrich, Jenna     59231           0        Area Sales Manager
# 79              Dunne, Amy   62514           0   Production Technician I
# 90     Fernandes, Nilson     64057           0   Production Technician I
# 91              Fett, Boba   53366           0          Network Engineer
# 190          Monroe, Peter  157000           0        IT Manager - Infra
# 246  Saar-Beckles, Melinda   47750           0   Production Technician I
# 258            Smith, John   72992           0             Sales Manager
# 263       Sparks, Taylor     64021           0   Production Technician I
# 267     Stansfield, Norman   58273           0        Area Sales Manager
# ...

# %%
# Employees with less engagement score are present in the department Production
lp.groupby('Department').agg({'Engagement_Survey':'count','Terminated':'count'})
# Out:
#                    Engagement_Survey  Terminated
# Department
# IT/IS                              2           2
# Production                         7           7
# Sales                              5           5
